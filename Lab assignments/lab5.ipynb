# %%
#TASK-1
import math
class Circle:
  def __init__(self,radius):
    self.__radius=radius
  def setRadius(self,radius):
    self.__radius=radius
  def getRadius(self):
    return self.__radius
  def area(self):
    ar=math.pi*self.__radius**2
    return ar


###################################
c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" , c1.area())

c2 = Circle(5)
print("Second circle radius:" , c2.getRadius())
print("Second circle area:" , c2.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483

# %%
#TASK-2
class Triangle:
  def __init__(self,base,height):
    self.__base=base
    self.__height=height
  def setBase(self,base):
    self.__base=base
  def setHeight(slef,height):
    self.height=height
  def getBase(self):
    return self.__base
  def getHeight(self):
    return self.__height
  def area(self):
    area=0.5*self.__base*self.__height
    return area



######################################################
t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())


t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5

# %%
#TASK-3
class Course:
  def __init__(self,title):
    self.title=title
class Teacher:
  def __init__(self,name,dept):
    self.__name=name
    self.__dept=dept
    self.__courses=[]
  def getName(self):
    return self.__name
  def getDept(self):
    return self.__dept
  def addCourse(self,obj):
    self.__courses.append(obj.title)
  def printDetail(self):
    print("==========================================")
    print(f"Name :{self.getName()}\nDepartment :{self.getDept()}")
    print("List of courses")
    print("==========================================")
    for i in self.__courses:
      print(i)
    print("==========================================")


############################################
t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object Oriented Programming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# Name :Saad Abdullah
# Department :CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name :Mumit Khan
# Department :CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CSE 230 Discrete Mathematics
# ...
# Name :Sadia Kazi
# Department :CSE
# List of courses
# ...
# CSE 310 Object Oriented Programming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
#TASK-4
class Player:
  def __init__(self,name):
    self.name=name
class Team:
  def __init__(self,tname=None):
    self.__tname=tname
    self.__players=[]
  def setName(self,tname):
    self.__tname=tname
  def addPlayer(self,obj):
    self.__players.append(obj.name)
  def printDetail(self):
    print("===========================================")
    print(f"Name :{self.__tname}\nList of players:\n{self.__players}")
    print("===========================================")


###########################################
b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Name :Bangladesh
# List of players:
# ['Mashrafi', 'Tamim']
# ...
# Name :Australia
# List of players:
# ['Ponting', 'Lee']
# ...

# %%
#TASK-5
class Student:
  def __init__(self,name,id,dept):
    self.name=name
    self.id=id
    self.dept=dept
    self.courses=[]
    self.email=None
    self.password=None
    self.login_status=None
    print("Student object is created!")
class Usis:
  def __init__(self):
    print("USIS is ready to use!")
  def login(self,obj):
    if obj.email==None or obj.password==None:
      obj.login_status=None
      print("Email and password need to be set.")
    else:
      obj.login_status=True
      print("login successful!")
  def advising (self, *args):
    student=args[0]
    if student.login_status==None:
      print("Please login to advise courses!")
    else:
      if len(args)==1:
        print("You haven't selected any courses.")
      elif len(args)>4:
        print("You need special approval to take more than 3 courses.")
      else:
        # student=args[0]
        for i in args[1:len(args)]:
          student.courses.append(i)
        print("Advising successful!")
  def individualDetails(self,obj):
    out=""
    for i in range(len(obj.courses)) :
      if i !=len(obj.courses)-1:
        out+=obj.courses[i]+", "
      else:
        out+=obj.courses[i]
    return f"Name :{obj.name}\nID : {obj.id}\nDepartment : {obj.dept}\nAdvised courses : {out}"



##############################################
rakib = Student("Rakib", 12301455, "CSE")
print("1***********************")
usis_obj = Usis()
print("2***********************")
usis_obj.login(rakib)
print("3***********************")
usis_obj.advising(rakib)
print("4***********************")
rakib.email = "rakib@hotmail.com"
rakib.password = "1234"
print("5***********************")
usis_obj.login(rakib)
print("6***********************")
usis_obj.advising(rakib)
print("7***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110", "CSE260")
print("8***********************")
usis_obj.advising(rakib, "CSE110", "PHY111", "MAT110")
print("9***********************")
print(usis_obj.individualDetails(rakib))
# Out:
# Student object is created!
# 1***********************
# USIS is ready to use!
# 2***********************
# Email and password need to be set.
# 3***********************
# Please login to advise courses!
# 4***********************
# 5***********************
# login successful!
# 6***********************
# You haven't selected any courses.
# 7***********************
# You need special approval to take more than 3 courses.
# 8***********************
# Advising successful!
# 9***********************
# Name :Rakib
# ID : 12301455
# Department : CSE
# Advised courses : CSE110, PHY111, MAT110

# %%
#TASK-6
class Passenger:
  def __init__(self,name,start=None,destination=None):
    self.name=name
    self.start=start
    self.destination=destination
class Train:
  def __init__(self,*args):
    self.train=args[0]
    self.stations=[]
    self.passengers=[]
    for i in args[1:len(args):]:
      self.stations.append(i)
    print(f"Welcome aboard on {self.train}\nStart:{self.stations[0]}\nDestination : {self.stations[-1]} ")
  def addPassenger(self,*obj):
    for i in obj:
      self.passengers.append(i)
      print(f"{i.name} welcome aboard")
      if i.start==None:
        i.start=self.stations[0]
      if i.destination==None:
        i.destination=self.stations[-1]
      i.fare=(self.stations.index(i.destination)-self.stations.index(i.start))*100

  def allPassengerDetails(self):
    for i in self.passengers:
      print(f"Name : {i.name}, Start :{i.start}, Destination : {i.destination}, Fare : {i.fare}")


############################################################
t1 = Train('T1-Express','New York','Manhattan','Brooklyn','Boston')
print("1========================")
p1 =Passenger("Naruto")
t1.addPassenger(p1)
p2 = Passenger("Sasuke","Manhattan")
p3 = Passenger("Hinata","Manhattan","Brooklyn")
print("2========================")
t1.addPassenger(p2,p3)
print("3========================")
t1.allPassengerDetails()
print("4========================")
t2 = Train('Europe-Express','London','Paris','Brussels','Turkey')
print("5========================")
p4 =Passenger("Max","London","Brussels")
p5 = Passenger("Eleven","Paris")
p6 = Passenger("Mike","Brussels")
t2.addPassenger(p4,p5,p6)
print("6========================")
t2.allPassengerDetails()
# Out:
# Welcome aboard on T1-Express
# Start:New York
# Destination : Boston
# 1========================
# Naruto welcome aboard
# 2========================
# Sasuke welcome aboard
# Hinata welcome aboard
# 3========================
# Name : Naruto, Start :New York, Destination : Boston, Fare : 300
# Name : Sasuke, Start :Manhattan, Destination : Boston, Fare : 200
# Name : Hinata, Start :Manhattan, Destination : Brooklyn, Fare : 100
# 4========================
# Welcome aboard on Europe-Express
# Start:London
# Destination : Turkey
# 5========================
# Max welcome aboard
# Eleven welcome aboard
# Mike welcome aboard
# 6========================
# Name : Max, Start :London, Destination : Brussels, Fare : 200
# Name : Eleven, Start :Paris, Destination : Turkey, Fare : 200
# Name : Mike, Start :Brussels, Destination : Turkey, Fare : 100

# %%
#TASK-7
class BracuStudent:
  def __init__(self,name,home):
    self.name=name
    self.home=home
    self.paas=False
  def get_pass(self):
    self.paas=True
  def show_details(self):
    print(f"Student Name : {self.name}\nLives in {self.home}\nHave bus pass? {self.paas}")


class BracuBus:
  def __init__(self,route,capacity=2):
    self.route=route
    self.capacity=capacity
    self.passengers=[]
  def show_details(self):
    print(f"Bus Route : {self.route}\nPassengers count : {len(self.passengers)} (Max : {self.capacity})\nPassengers On board : {self.passengers}")
  def board(self,*persons):
    if len(persons)==0:
      print("No passenger!")
    else:
      for i in persons:
        if i.paas==True:
          if i.home!=self.route:
            print("You got on wrong bus!")
          else:
            if len(self.passengers)<(self.capacity):
              self.passengers.append(i.name)
              print(f"{i.name} boarded the bus")
            else:
              print("Bus is full!")
        else:
          print("You don't have bus pass!")



############################################################################


st1 = BracuStudent("Afif", "Mirpur")
print("1===========================")
st2 = BracuStudent("Shanto", "Motijheel")
st3 = BracuStudent("Taskin", "Mirpur")
st1.show_details()
st2.show_details()
print("2===========================")
st3.show_details()
print("3===========================")
bus1 = BracuBus("Mirpur")
bus2 = BracuBus("Azimpur", 5)
bus1.show_details()
bus2.show_details()
print("4===========================")
st2.get_pass()
st3.get_pass()
print("5===========================")
st2.show_details()
st3.show_details()
print("6===========================")
bus1.board()
print("7===========================")
bus1.board(st1, st2)
print("8===========================")
st1.get_pass()
st2.home = "Mirpur"
st1.show_details()
st2.show_details()
print("9===========================")
bus1.board(st1, st2, st3)
print("10===========================")
bus1.show_details()
# Out:
# 1===========================
# Student Name : Afif
# Lives in Mirpur
# Have bus pass? False
# Student Name : Shanto
# Lives in Motijheel
# Have bus pass? False
# 2===========================
# Student Name : Taskin
# Lives in Mirpur
# Have bus pass? False
# 3===========================
# Bus Route : Mirpur
# Passengers count : 0 (Max : 2)
# Passengers On board : []
# Bus Route : Azimpur
# Passengers count : 0 (Max : 5)
# Passengers On board : []
# 4===========================
# 5===========================
# Student Name : Shanto
# Lives in Motijheel
# Have bus pass? True
# Student Name : Taskin
# Lives in Mirpur
# Have bus pass? True
# 6===========================
# No passenger!
# 7===========================
# You don't have bus pass!
# You got on wrong bus!
# 8===========================
# Student Name : Afif
# Lives in Mirpur
# Have bus pass? True
# Student Name : Shanto
# Lives in Mirpur
# Have bus pass? True
# 9===========================
# Afif boarded the bus
# ...

# %%
#TASK-8
class Library:
  def __init__(self,name,available):
    self.name=name
    self.available=available
    self.borrower={}

  def details(self):
    print(f"{self.name} Library details")
    print(f"Borrower details :\n{self.borrower}")
    print(f"Books availabilty :\n{self.available}")

class Reader:
  def __init__(self,name):
    self.name=name
    self.borrowed_books=0
    self.taken={}

  def borrow(self,*args):
    lib=args[0]
    for i in args[1:len(args):]:
      if self.borrowed_books<5:
        if lib.available[i]>0:
          if i not in self.taken.keys():
            self.taken.update({i:1})
          else:
            self.taken[i]+=1
          self.borrowed_books+=1
          print(f"{i} book is borrowed succesfully")
          lib.available[i]-=1
        else:
          print(f"{i} books are not available at the moment.")
      else:
          print("You cannot borrow more than 5 books.")
    lib.borrower[self.name]=self.borrowed_books

  def readerInfo(self,book=None):
    if book==None:
      print(f"{self.name}, you have {self.borrowed_books} book(s) with you")
      for k,v in self.taken.items():
        print(f"Books on {k}:{v}")
    else:
      print(f"{self.name}, you have {self.taken[book]} {book} book(s) with you.")

############################################################

L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details :
# {}
# Books availabilty :
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed succesfully
# Fiction book is borrowed succesfully
# Fiction book is borrowed succesfully
# Politics book is borrowed succesfully
# 2----------------------
# Politics book is borrowed succesfully
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 5 book(s) with you
# Books on Arts:1
# Books on Fiction:2
# Books on Politics:2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details :
# {'Aladdin': 5}
# Books availabilty :
# {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics books are not available at the moment.
# Poetry book is borrowed succesfully
# 7----------------------
# Jasmine, you have 1 book(s) with you
# ...

# %%
#TASK-8
class Library:
  def __init__(self,name,available):
    self.name=name
    self.available=available
    self.borrower={}

  def details(self):
    print(f"{self.name} Library details")
    print(f"Borrower details :\n{self.borrower}")
    print(f"Books availabilty :\n{self.available}")

class Reader:
  def __init__(self,name):
    self.name=name
    self.borrowed_books=0
    self.taken={}

  def borrow(self,*args):
    lib=args[0]
    for i in range(1,len(args)):
      if self.borrowed_books<5:
        if lib.available[args[i]]>0:
          if args[i] not in self.taken.keys():
            self.taken.update({args[i]:1})
            self.borrowed_books+=1
            print(f"{args[i]} book is borrowed succesfully")
          else:
            self.taken[args[i]]+=1
            self.borrowed_books+=1
            print(f"{args[i]} book is borrowed succesfully")
          lib.available[args[i]]-=1
        else:
          print(f"{args[i]} books are not available at the moment.")
      else:
          print("You cannot borrow more than 5 books.")
    lib.borrower[self.name]=self.borrowed_books

  def readerInfo(self,book=None):
    if book==None:
      print(f"{self.name}, you have {self.borrowed_books} book(s) with you")
      for k,v in self.taken.items():
        print(f"Books on {k}:{v}")
    else:
      print(f"{self.name}, you have {self.taken[book]} {book} book(s) with you.")







############################################################

L1=Library('Dhaka',{'Arts':15,'Fiction':135,'Politics':2,'Science':11,'Poetry':15})
L1.details()
print("1----------------------")
r1=Reader('Aladdin')
r1.borrow(L1,'Arts','Fiction','Fiction','Politics')
print("2----------------------")
r1.borrow(L1,'Politics','Fiction')
print("3----------------------")
r1.readerInfo()
print("4----------------------")
r1.readerInfo('Fiction')
print("5----------------------")
L1.details()
print("6----------------------")
r2=Reader('Jasmine')
r2.borrow(L1,'Politics','Poetry')
print("7----------------------")
r2.readerInfo()
print("8----------------------")
L1.details()
# Out:
# Dhaka Library details
# Borrower details :
# {}
# Books availabilty :
# {'Arts': 15, 'Fiction': 135, 'Politics': 2, 'Science': 11, 'Poetry': 15}
# 1----------------------
# Arts book is borrowed succesfully
# Fiction book is borrowed succesfully
# Fiction book is borrowed succesfully
# Politics book is borrowed succesfully
# 2----------------------
# Politics book is borrowed succesfully
# You cannot borrow more than 5 books.
# 3----------------------
# Aladdin, you have 5 book(s) with you
# Books on Arts:1
# Books on Fiction:2
# Books on Politics:2
# 4----------------------
# Aladdin, you have 2 Fiction book(s) with you.
# 5----------------------
# Dhaka Library details
# Borrower details :
# {'Aladdin': 5}
# Books availabilty :
# {'Arts': 14, 'Fiction': 133, 'Politics': 0, 'Science': 11, 'Poetry': 15}
# 6----------------------
# Politics books are not available at the moment.
# Poetry book is borrowed succesfully
# 7----------------------
# Jasmine, you have 1 book(s) with you
# ...
